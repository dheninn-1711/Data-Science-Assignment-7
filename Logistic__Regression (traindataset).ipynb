# %%
#import libraries
import pandas as pd

# %%
#load the dataframe
data=pd.read_csv("C:\\Users\\dheni\\Downloads\\DS Assignments\\7.Logistic Regression\\Titanic_train.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data=data.drop(['Survived'],axis=1)
data
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
#summary of numerical variables
data.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#datatypes in dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Pclass       891 non-null    int64
#  2   Name         891 non-null    object
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
#summary of categorical variables
data.describe(include=['object'])
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data=data.dropna()
data.shape
# Out:
# (183, 11)

# %%
#import libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Histograms 
data.hist(figsize=(12,10))
plt.title("Histogram of Variables")
plt.show()

# %%
#boxplots
sns.boxplot(data=data)
plt.show()

# %%
#missing values
data.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
#import library
from sklearn.preprocessing import LabelEncoder
# Initialize LabelEncoder
label_encoder = LabelEncoder()
# Encode 'Sex' and 'Embarked' in data
data['Sex'] = label_encoder.fit_transform(data['Sex'])
data['Embarked'] = label_encoder.fit_transform(data['Embarked'])
data
# Out:
#      PassengerId  Pclass                                               Name  \
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6              7       1                            McCarthy, Mr. Timothy J
# 10            11       3                    Sandstrom, Miss. Marguerite Rut
# 11            12       1                           Bonnell, Miss. Elizabeth
# ..           ...     ...                                                ...
# 871          872       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872          873       1                           Carlsson, Mr. Frans Olof
# 879          880       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887          888       1                       Graham, Miss. Margaret Edith
# 889          890       1                              Behr, Mr. Karl Howell
#
# ...

# %%
#drop unnecessary columns
data.drop(columns=['PassengerId', 'Name', 'Ticket', 'Cabin'], inplace=True)
data
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 1         1    0  38.0      1      0  71.2833         0
# 3         1    0  35.0      1      0  53.1000         2
# 6         1    1  54.0      0      0  51.8625         2
# 10        3    0   4.0      1      1  16.7000         2
# 11        1    0  58.0      0      0  26.5500         2
# ..      ...  ...   ...    ...    ...      ...       ...
# 871       1    0  47.0      1      1  52.5542         2
# 872       1    1  33.0      0      0   5.0000         2
# 879       1    0  56.0      0      1  83.1583         0
# 887       1    0  19.0      0      0  30.0000         2
# 889       1    1  26.0      0      0  30.0000         0
#
# [183 rows x 7 columns]

# %%
#Handle missing values of Y
y = pd.to_numeric(y, errors='coerce')
y = y.fillna(y.mode()[0])  # Handle any remaining NaNs in y

# Handle missing values in X
X = X.apply(pd.to_numeric, errors='coerce')  # Ensure all data in X is numeric
X.fillna(X.mean(), inplace=True)  # Fill missing values with the mean of each column

# Split data into training and validation sets
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state=0)

# Initialize and train the model
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#import library
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve

# %%
# Predict on the validation set
y_pred = model.predict(X_valid)
y_prob = model.predict_proba(X_valid)[:, 1]

# Calculate metrics
accuracy = accuracy_score(y_valid, y_pred)
precision = precision_score(y_valid, y_pred)
recall = recall_score(y_valid, y_pred)
f1 = f1_score(y_valid, y_pred)
roc_auc = roc_auc_score(y_valid, y_prob)
#Print the values
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
print(f'ROC AUC Score: {roc_auc}')
# Out:
# Accuracy: 0.7709923664122137
# Precision: 0.68
# Recall: 0.4358974358974359
# F1 Score: 0.53125
# ROC AUC Score: 0.8121516164994426

# %%
#ROC curve
fpr, tpr, _ = roc_curve(y_valid, model.predict_proba(X_valid)[:, 1])
plt.plot(fpr, tpr, color='red', label='Logistic Regression')
plt.plot([0,1],[0,1],'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
# Coefficients of the logistic regression model
coefficients = model.coef_
feature_names = X.columns
#print values
for feature, coef in zip(feature_names, coefficients):
    print(f'Feature: {feature}, Coefficient: {coef}')
# Out:
# Feature: Pclass, Coefficient: [-7.67793385e-01 -1.62907341e+00 -2.81421408e-02 -1.81497737e-01
#   3.30224958e-02  7.59143161e-04 -1.01307653e-01]

# %% [markdown]
# Significance:
#
# Feature Coefficients: Positive coefficients increase the likelihood of survival, while negative coefficients decrease it. Larger magnitudes indicate stronger effects.

# %%
#import libraries
import streamlit as st
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
import pickle

# %%
#load the model
filename='logistic_model.pkl'
pickle.dump(model,open(filename, 'wb'))

# %% [markdown]
# Interview Questions:
#
# 1. What is the difference between precision and recall?
#
# Precision is the ratio of true positive predictions to the total number of positive predictions (true positives + false positives). It measures the accuracy of the positive predictions.
#
# Recall (or Sensitivity) is the ratio of true positive predictions to the total number of actual positives (true positives + false negatives). It measures the ability of the model to identify all positive instances.
#
# ​2. What is cross-validation, and why is it important in binary classification?
#
# Cross-validation is a technique used to evaluate the performance of a model by partitioning the data into subsets.
#
# Importance:
#
# Helps in assessing how well the model generalizes to an independent dataset.
#
# Offers a more reliable estimate of model performance by averaging results across different folds.
#
# Ensures that each data point is used for both training and testing, leading to a more robust evaluation.
